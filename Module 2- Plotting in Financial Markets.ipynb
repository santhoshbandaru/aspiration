# %% [markdown]
# # Module 2- Plotting in Financial Markets

# %% [markdown]
#    ### Welcome to the Answer notebook for Module 2 !
# Make sure that you've submitted the module 1 notebook and unlocked Module 2 yourself before you start coding here

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#

# %% [markdown]
# ### Query 2.1
# Load the week2.csv file into a dataframe. What is the type of the Date column? Make sure it is of type datetime64. Convert the Date column to the index of the dataframe.
# Plot the closing price of each of the days for the entire time frame to get an idea of what the general outlook of the stock is.
#
# >Look out for drastic changes in this stock, you have the exact date when these took place, try to fetch the news for this day of this stock
#
# >This would be helpful if we are to train our model to take NLP inputs.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('week2.csv',parse_dates=['Date'])
data.set_index('Date',inplace=True)
import seaborn as sns

# %%
data
# Out:
#                 Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15  AJANTPHARM     EQ     1616.30     1610.00     1643.40    1601.00
# 2017-05-16  AJANTPHARM     EQ     1633.50     1632.50     1643.45    1610.00
# 2017-05-17  AJANTPHARM     EQ     1634.25     1620.50     1668.00    1620.50
# 2017-05-18  AJANTPHARM     EQ     1654.35     1640.25     1663.95    1621.85
# 2017-05-19  AJANTPHARM     EQ     1633.40     1640.00     1681.20    1621.50
# 2017-05-22  AJANTPHARM     EQ     1670.25     1670.00     1692.00    1648.00
# 2017-05-23  AJANTPHARM     EQ     1677.95     1687.80     1696.95    1619.00
# 2017-05-24  AJANTPHARM     EQ     1676.80     1672.00     1693.00    1623.30
# 2017-05-25  AJANTPHARM     EQ     1657.45     1650.00     1654.85    1578.05
# 2017-05-26  AJANTPHARM     EQ     1616.15     1615.00     1625.40    1569.15
# 2017-05-29  AJANTPHARM     EQ     1602.15     1597.00     1599.90    1401.65
# 2017-05-30  AJANTPHARM     EQ     1536.30     1520.20     1565.05    1518.00
# 2017-05-31  AJANTPHARM     EQ     1549.00     1560.00     1588.95    1541.40
# 2017-06-01  AJANTPHARM     EQ     1569.80     1569.00     1615.40    1560.00
# 2017-06-02  AJANTPHARM     EQ     1606.40     1629.00     1629.60    1589.00
# 2017-06-05  AJANTPHARM     EQ     1607.55     1613.00     1628.00    1595.00
# 2017-06-06  AJANTPHARM     EQ     1604.40     1618.00     1618.00    1571.65
# 2017-06-07  AJANTPHARM     EQ     1580.85     1580.85     1585.60    1558.00
# 2017-06-08  AJANTPHARM     EQ     1562.90     1577.00     1600.00    1557.00
# 2017-06-09  AJANTPHARM     EQ     1569.10     1572.00     1592.00    1558.25
# 2017-06-12  AJANTPHARM     EQ     1570.55     1560.00     1580.00    1549.50
# 2017-06-13  AJANTPHARM     EQ     1559.50     1557.00     1565.90    1541.00
# 2017-06-14  AJANTPHARM     EQ     1544.75     1545.00     1590.00    1521.75
# 2017-06-15  AJANTPHARM     EQ     1585.85     1587.00     1601.00    1570.20
# 2017-06-16  AJANTPHARM     EQ     1579.75     1575.00     1592.10    1548.00
# 2017-06-19  AJANTPHARM     EQ     1559.65     1568.00     1569.95    1533.50
# 2017-06-20  AJANTPHARM     EQ     1544.55     1542.70     1549.00    1507.20
# 2017-06-21  AJANTPHARM     EQ     1535.30     1540.00     1547.45    1521.05
# 2017-06-22  AJANTPHARM     EQ     1534.10     1544.00     1545.50    1516.15
# 2017-06-23  AJANTPHARM     EQ     1522.65     1522.75     1533.60    1506.00
# ...                ...    ...         ...         ...         ...        ...
# 2019-03-27  AJANTPHARM     EQ     1010.95     1014.80     1024.00     979.10
# 2019-03-28  AJANTPHARM     EQ     1000.95     1008.00     1030.80    1005.30
# 2019-03-29  AJANTPHARM     EQ     1025.40     1030.00     1064.40    1028.10
# 2019-04-01  AJANTPHARM     EQ     1035.20     1038.10     1050.00    1028.55
# 2019-04-02  AJANTPHARM     EQ     1034.90     1046.00     1047.45    1021.60
# 2019-04-03  AJANTPHARM     EQ     1032.40     1032.50     1039.75    1016.15
# 2019-04-04  AJANTPHARM     EQ     1023.40     1023.70     1030.00    1008.75
# 2019-04-05  AJANTPHARM     EQ     1020.75     1025.00     1036.50    1015.85
# 2019-04-08  AJANTPHARM     EQ     1026.00     1029.20     1037.00    1010.60
# 2019-04-09  AJANTPHARM     EQ     1019.05     1020.05     1025.90    1008.00
# 2019-04-10  AJANTPHARM     EQ     1021.20     1017.00     1023.95    1008.55
# 2019-04-11  AJANTPHARM     EQ     1013.90     1018.40     1022.00    1009.00
# 2019-04-12  AJANTPHARM     EQ     1014.65     1017.85     1029.40    1014.65
# 2019-04-15  AJANTPHARM     EQ     1019.55     1020.50     1030.00    1019.50
# 2019-04-16  AJANTPHARM     EQ     1027.15     1031.00     1050.00    1028.05
# 2019-04-18  AJANTPHARM     EQ     1032.60     1043.00     1043.00    1018.90
# 2019-04-22  AJANTPHARM     EQ     1027.00     1020.00     1020.00    1001.25
# 2019-04-23  AJANTPHARM     EQ     1015.00     1013.00     1038.00    1009.00
# 2019-04-24  AJANTPHARM     EQ     1028.05     1029.05     1039.50    1016.00
# 2019-04-25  AJANTPHARM     EQ     1023.35     1022.00     1046.00    1022.00
# 2019-04-26  AJANTPHARM     EQ     1029.90     1025.20     1037.30    1006.30
# 2019-04-30  AJANTPHARM     EQ     1026.65     1032.65     1035.00     984.00
# 2019-05-02  AJANTPHARM     EQ      990.40      970.00     1089.40     970.00
# 2019-05-03  AJANTPHARM     EQ     1072.90     1060.00     1084.65    1041.00
# 2019-05-06  AJANTPHARM     EQ     1051.70     1030.00     1075.00    1028.45
# 2019-05-07  AJANTPHARM     EQ     1067.70     1075.00     1080.00    1046.00
# 2019-05-08  AJANTPHARM     EQ     1051.40     1048.00     1064.90    1043.00
# 2019-05-09  AJANTPHARM     EQ     1057.95     1050.00     1069.90    1048.50
# 2019-05-10  AJANTPHARM     EQ     1064.40     1070.95     1082.00    1056.05
# 2019-05-13  AJANTPHARM     EQ     1068.35     1066.00     1068.00    1034.00
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-15     1636.00      1633.50        1626.20                  80998
# 2019-05-06                   19.24      5  2019         1.521346
# 2019-05-07                    6.64      5  2019        -1.526646
# 2019-05-08                   13.30      5  2019         0.622979
# 2019-05-09                   10.62      5  2019         0.609670
# 2019-05-10                   11.48      5  2019         0.371101
# 2019-05-13                   10.48      5  2019        -2.297936
#
#                           Trend
# Date
# 2017-05-15  Slight or No change
# 2017-05-16  Slight or No change
# 2017-05-17             Positive
# 2017-05-18             Negative
# 2017-05-19             Positive
# 2017-05-22  Slight or No change
# 2017-05-23  Slight or No change
# 2017-05-24             Negative
# 2017-05-25             Negative
# 2017-05-26      Slight Negative
# 2017-05-29     Among top losers
# 2017-05-30      Slight Positive
# 2017-05-31             Positive
# 2017-06-01             Positive
# 2017-06-02  Slight or No change
# 2017-06-05  Slight or No change
# 2017-06-06             Negative
# 2017-06-07             Negative
# 2017-06-08  Slight or No change
# 2017-06-09  Slight or No change
# 2017-06-12      Slight Negative
# 2017-06-13      Slight Negative
# 2017-06-14             Positive
# 2017-06-15  Slight or No change
# 2017-06-16             Negative
# 2017-06-19      Slight Negative
# 2017-06-20      Slight Negative
# 2017-06-21  Slight or No change
# 2017-06-22      Slight Negative
# 2017-06-23      Slight Negative
# ...                         ...
# 2019-03-27      Slight Negative
# 2019-03-28             Positive
# 2019-03-29      Slight Positive
# 2019-04-01  Slight or No change
# 2019-04-02  Slight or No change
# 2019-04-03      Slight Negative
# 2019-04-04  Slight or No change
# 2019-04-05      Slight Positive
# 2019-04-08      Slight Negative
# 2019-04-09  Slight or No change
# 2019-04-10      Slight Negative
# 2019-04-11  Slight or No change
# 2019-04-12  Slight or No change
# 2019-04-15      Slight Positive
# 2019-04-16      Slight Positive
# 2019-04-18      Slight Negative
# 2019-04-22             Negative
# 2019-04-23             Positive
# 2019-04-24  Slight or No change
# 2019-04-25      Slight Positive
# 2019-04-26  Slight or No change
# 2019-04-30     Among top losers
# 2019-05-02             Bull run
# 2019-05-03             Negative
# 2019-05-06             Positive
# 2019-05-07             Negative
# 2019-05-08      Slight Positive
# 2019-05-09      Slight Positive
# 2019-05-10  Slight or No change
# 2019-05-13             Negative
#
# [494 rows x 18 columns]

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# %%
fig,ax=plt.subplots(figsize=(10,8))
data['Close Price'].plot(ax=ax,grid=True)
ax.set(xlabel="Date",ylabel="Close Price")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.setp(ax.get_xticklabels(),rotation=45);

# %%
gr=data["Close Price"].plot(grid=True)

# %%
# !pip install cufflinks --user
# Out:
# Requirement already satisfied: cufflinks in /home/a3875521/.local/lib/python3.6/site-packages (0.16)
# Requirement already satisfied: ipywidgets>=7.0.0 in /opt/anaconda/lib/python3.6/site-packages (from cufflinks) (7.2.1)
# Requirement already satisfied: plotly<4.0.0a0,>=3.0.0 in /home/a3875521/.local/lib/python3.6/site-packages (from cufflinks) (3.10.0)
# Requirement already satisfied: ipython>=5.3.0 in /opt/anaconda/lib/python3.6/site-packages (from cufflinks) (6.4.0)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda/lib/python3.6/site-packages (from cufflinks) (1.11.0)
# Requirement already satisfied: numpy>=1.9.2 in /opt/anaconda/lib/python3.6/site-packages (from cufflinks) (1.14.3)
# Requirement already satisfied: setuptools>=34.4.1 in /opt/anaconda/lib/python3.6/site-packages (from cufflinks) (39.1.0)
# Requirement already satisfied: colorlover>=0.2.1 in /home/a3875521/.local/lib/python3.6/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: pandas>=0.19.2 in /opt/anaconda/lib/python3.6/site-packages (from cufflinks) (0.23.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/anaconda/lib/python3.6/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.8.2)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda/lib/python3.6/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.3.2)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/anaconda/lib/python3.6/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: widgetsnbextension~=3.2.0 in /opt/anaconda/lib/python3.6/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.2.1)
# Requirement already satisfied: pytz in /opt/anaconda/lib/python3.6/site-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (2018.4)
# Requirement already satisfied: retrying>=1.3.3 in /home/a3875521/.local/lib/python3.6/site-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (1.3.3)
# Requirement already satisfied: requests in /opt/anaconda/lib/python3.6/site-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (2.18.4)
# Requirement already satisfied: decorator>=4.0.6 in /opt/anaconda/lib/python3.6/site-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (4.3.0)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda/lib/python3.6/site-packages (from ipython>=5.3.0->cufflinks) (0.12.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.15 in /opt/anaconda/lib/python3.6/site-packages (from ipython>=5.3.0->cufflinks) (1.0.15)
# Requirement already satisfied: pygments in /opt/anaconda/lib/python3.6/site-packages (from ipython>=5.3.0->cufflinks) (2.2.0)
# Requirement already satisfied: simplegeneric>0.8 in /opt/anaconda/lib/python3.6/site-packages (from ipython>=5.3.0->cufflinks) (0.8.1)
# Requirement already satisfied: backcall in /opt/anaconda/lib/python3.6/site-packages (from ipython>=5.3.0->cufflinks) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda/lib/python3.6/site-packages (from ipython>=5.3.0->cufflinks) (4.5.0)
# Requirement already satisfied: pickleshare in /opt/anaconda/lib/python3.6/site-packages (from ipython>=5.3.0->cufflinks) (0.7.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/anaconda/lib/python3.6/site-packages (from pandas>=0.19.2->cufflinks) (2.7.3)
# Requirement already satisfied: jupyter_client in /opt/anaconda/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.2.3)
# Requirement already satisfied: tornado>=4.0 in /opt/anaconda/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.0.2)
# Requirement already satisfied: ipython_genutils in /opt/anaconda/lib/python3.6/site-packages (from traitlets>=4.3.1->ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/anaconda/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (2.6.0)
# Requirement already satisfied: jupyter_core in /opt/anaconda/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: notebook>=4.4.1 in /opt/anaconda/lib/python3.6/site-packages (from widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (5.5.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda/lib/python3.6/site-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /opt/anaconda/lib/python3.6/site-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /opt/anaconda/lib/python3.6/site-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda/lib/python3.6/site-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (2018.4.16)
# Requirement already satisfied: parso>=0.2.0 in /opt/anaconda/lib/python3.6/site-packages (from jedi>=0.10->ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: wcwidth in /opt/anaconda/lib/python3.6/site-packages (from prompt-toolkit<2.0.0,>=1.0.15->ipython>=5.3.0->cufflinks) (0.1.7)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->cufflinks) (0.5.2)
# Requirement already satisfied: pyzmq>=13 in /opt/anaconda/lib/python3.6/site-packages (from jupyter_client->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (17.0.0)
# Requirement already satisfied: terminado>=0.8.1 in /opt/anaconda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (0.8.1)
# Requirement already satisfied: Send2Trash in /opt/anaconda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: nbconvert in /opt/anaconda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (5.3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (2.10)
# Requirement already satisfied: mistune>=0.7.4 in /opt/anaconda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (0.8.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/anaconda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: bleach in /opt/anaconda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (2.1.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (1.4.2)
# Requirement already satisfied: testpath in /opt/anaconda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (0.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda/lib/python3.6/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (1.0)
# Requirement already satisfied: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in /opt/anaconda/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (1.0.1)
# Requirement already satisfied: webencodings in /opt/anaconda/lib/python3.6/site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.2.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import cufflinks as cf
cf.set_config_file(world_readable=True,offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data["Close Price"].iplot()
# Out:
# <div>
#
#
#             <div id="6c6fc16c-b648-4c8f-8157-eed4503d8f6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6c6fc16c-b648-4c8f-8157-eed4503d8f6b")) {
#                     Plotly.newPlot(
#                         '6c6fc16c-b648-4c8f-8157-eed4503d8f6b',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Close Price", "text": "", "type": "scatter", "uid": "94efad5a-adb6-4acd-b41f-97bb931ec435", "x": ["2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-29", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-04", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-23", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-01", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-15", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-12", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-19", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-23", "2018-02-26", "2018-02-27", "2018-02-28", "2018-03-01", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-08", "2018-03-09", "2018-03-12", "2018-03-13", "2018-03-14", "2018-03-15", "2018-03-16", "2018-03-19", "2018-03-20", "2018-03-21", "2018-03-22", "2018-03-23", "2018-03-26", "2018-03-27", "2018-03-28", "2018-04-02", "2018-04-03", "2018-04-04", "2018-04-05", "2018-04-06", "2018-04-09", "2018-04-10", "2018-04-11", "2018-04-12", "2018-04-13", "2018-04-16", "2018-04-17", "2018-04-18", "2018-04-19", "2018-04-20", "2018-04-23", "2018-04-24", "2018-04-25", "2018-04-26", "2018-04-27", "2018-04-30", "2018-05-02", "2018-05-03", "2018-05-04", "2018-05-07", "2018-05-08", "2018-05-09", "2018-05-10", "2018-05-11", "2018-05-14", "2018-05-15", "2018-05-16", "2018-05-17", "2018-05-18", "2018-05-21", "2018-05-22", "2018-05-23", "2018-05-24", "2018-05-25", "2018-05-28", "2018-05-29", "2018-05-30", "2018-05-31", "2018-06-01", "2018-06-04", "2018-06-05", "2018-06-06", "2018-06-07", "2018-06-08", "2 ...

# %% [markdown]
# # Query 2.2

# %% [markdown]
#  A stem plot is a discrete series plot, ideal for plotting daywise data. It can be plotted using the plt.stem() function.
#
# Display a stem plot of the daily change in of the stock price in percentage. This column was calculated in module 1 and should be already available in week2.csv. Observe whenever there's a large change.

# %%
fig,ax=plt.subplots(figsize=(18,8))
ax.stem(data.index,data['Day_Perc_Change'])
ax.set(xlabel="Date",ylabel="Close Price")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.setp(ax.get_xticklabels(),rotation=90);

# %% [markdown]
# # Query 2.3
#  Plot the daily volumes as well and compare the percentage stem plot to it. Document your analysis of the relationship between volume and daily percentage change.

# %%
def norm(data):
    return (data)/(max(data)-min(data))*10

# %%
fig,ax=plt.subplots(figsize=(18,8))
ax.plot(data.index,data['No. of Trades'])
ax.set(xlabel="Date",ylabel="Close Price")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.setp(ax.get_xticklabels(),rotation=90);

# %%
fig = plt.figure(figsize=(18,10))

plt.stem(data.index, data['Day_Perc_Change'], 'red')
plt.plot(data.index, norm(data['No. of Trades']), 'black')
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.show()

# %% [markdown]
# The Graph has been normalized to accomodate the two clearly on the same graph.
# From the graph,it is clear that there is a linear relationship between volume and daily percentage change of close price.
# Whenever there is a rise in no.of trades or volume,there is a rise in daily percentage change and vice versa.

# %% [markdown]
# # Query 2.4
# We had created a Trend column in module 1. We want to see how often each Trend type occurs. This can be seen as a pie chart, with each sector representing the percentage of days each trend occurs. Plot a pie chart for all the 'Trend' to know about relative frequency of each trend. You can use the groupby function with the trend column to group all days with the same trend into a single group before plotting the pie chart. From the grouped data, create a BAR plot of average & median values of the 'Total Traded Quantity' by Trend type.

# %%
data['Trend'].value_counts().plot(kind='pie',subplots=True,autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fb900318278>],
#       dtype=object)

# %%
import matplotlib.patches as mpatches

# %%
f, (ax1,ax2) = plt.subplots(2,1)
f.set_figheight(15)
f.set_figwidth(15)
data.groupby('Trend')['Total Traded Quantity'].mean().plot(kind="bar", ax=ax1,grid=True, legend=True)
mean_patch = mpatches.Patch(color='blue', label='Mean')
ax1.xaxis.set_label_text("")
ax1.tick_params(    axis='x',  bottom=False,  top=False,    labelbottom=False)
ax1.set_title("Mean")
ax1.legend(handles=[mean_patch])

data.groupby('Trend')['Total Traded Quantity'].median().plot(kind='bar',grid=True, ax=ax2,legend=True)
ax2.yaxis.set_label_text("")
median_patch = mpatches.Patch(color='red', label='Median')
ax2.set_title("Median")
ax2.legend(handles=[median_patch])
fig.subplots_adjust(hspace=0.5)

# %% [markdown]
# # Query 2.5
# Plot the daily return (percentage) distribution as a histogram.
# Histogram analysis is one of the most fundamental methods of exploratory data analysis. In this case, it'd return a frequency plot of various values of percentage changes .

# %%
plt.figure()
data['Day_Perc_Change'].plot(kind='hist',title="Daily return percentage frequency")
plt.xlabel('Daily Returns Percentage')
# Out:
# Text(0.5,0,'Daily Returns Percentage')

# %% [markdown]
# # Query 2.6
# We next want to analyse how the behaviour of different stocks are correlated. The correlation is performed on the percentage change of the stock price instead of the stock price.
#
# Load any 5 stocks of your choice into 5 dataframes. Retain only rows for which ‘Series’ column has value ‘EQ’. Create a single dataframe which contains the ‘Closing Price’ of each stock. This dataframe should hence have five columns. Rename each column to the name of the stock that is contained in the column. Create a new dataframe which is a percentage change of the values in the previous dataframe. Drop Nan’s from this dataframe.
# Using seaborn, analyse the correlation between the percentage changes in the five stocks. This is extremely useful for a fund manager to design a diversified portfolio. To know more, check out these resources on correlation and diversification.

# %%
datas=['ADANIPOWER','AJANTPHARM','RELINFRA','LALPATHLAB','TATACHEM']

# %%
def df(filename):
    data= pd.read_csv(filename)
    data= data[data['Series'] == 'EQ']
    return data

# %%
adani=df('ADANIPOWER.csv')
ajant=df('AJANTPHARM.csv')
relinf=df('RELINFRA.csv')
tchem=df('TATACHEM.csv')
lplab=df('LALPATHLAB.csv')
jblfood=df('JUBLFOOD.csv')

# %%
corr_data=pd.concat([adani['Close Price'], ajant['Close Price'],lplab['Close Price'],relinf['Close Price'],tchem['Close Price'],jblfood['Close Price']],keys=['ADANIPOWER', 'AJANTPHARM','LALPATHLABS','RELINFRA','TATACHEM','JUBLFOOD'],axis=1)

# %%
# 485       44.90      990.40      1039.75    107.90    584.15   1342.80
# 486       44.45     1072.90      1044.30    110.25    582.75   1328.50
# 487       43.85     1051.70      1073.10    109.90    572.20   1345.90
# 488       42.80     1067.70      1044.35    106.10    580.40   1326.35
# 489       41.50     1051.40      1024.95    100.90    577.15   1299.85
# 490       41.35     1057.95      1013.10     99.45    576.50   1282.25
# 491       40.95     1064.40      1006.10    101.90    556.50   1262.45
# 492       41.45     1068.35       982.90    107.15    605.20   1268.80
# 493       38.45     1043.80       980.65    101.10    596.00   1264.50
# 494         NaN         NaN       976.25       NaN    590.25   1242.60
# 495         NaN         NaN          NaN       NaN    589.00       NaN
# 496         NaN         NaN          NaN       NaN    590.00       NaN
# 497         NaN         NaN          NaN       NaN    574.90       NaN
#
# [498 rows x 6 columns]

# %%
pct_data=corr_data.pct_change().dropna()

# %%
pct_data=corr_data.pct_change().dropna()
pct_data
# Out:
#      ADANIPOWER  AJANTPHARM  LALPATHLABS  RELINFRA  TATACHEM  JUBLFOOD
# 1      0.085950    0.000459     0.011492  0.009333  0.022388  0.024575
# 2      0.007610    0.012299     0.000823 -0.009492 -0.009008 -0.001523
# 3     -0.036254   -0.012664    -0.002139 -0.043949 -0.020686 -0.028311
# 4      0.015674    0.022560     0.000550 -0.015726 -0.013522 -0.001226
# 5     -0.029321    0.004610    -0.000439 -0.025108 -0.028469  0.011983
# 6     -0.050874   -0.000685    -0.025224 -0.052229  0.005009 -0.036057
# 7     -0.061977   -0.011540     0.008795 -0.061853 -0.009719 -0.016815
# 8      0.023214   -0.024918     0.003968  0.006988  0.032212  0.039429
# 9      0.008726   -0.008663    -0.005065  0.022830 -0.007883 -0.021922
# 10    -0.076125   -0.041101     0.007329 -0.111209 -0.003522 -0.052735
# 11     0.024345    0.008267     0.001055  0.022237  0.031073 -0.033179
# 12     0.012797    0.013428     0.003273  0.036580  0.001834  0.006325
# 13    -0.027076    0.023315    -0.003926  0.001462  0.014563 -0.002896
# 14     0.009276    0.000716     0.003498  0.009279  0.003530  0.020389
# 15    -0.014706   -0.001960     0.000830  0.017044 -0.003048  0.005586
# 16     0.016791   -0.014678     0.000166 -0.024680 -0.025480  0.017627
# 17     0.003670   -0.011355     0.011330  0.017599  0.005551  0.002782
# 18    -0.016453    0.003967    -0.009181 -0.015657  0.000000  0.009003
# 19    -0.003717    0.000924    -0.008329 -0.014555 -0.017121  0.005499
# 20     0.037313   -0.007036    -0.004116 -0.004431  0.010094 -0.009855
# 21    -0.012590   -0.009458     0.013292 -0.003497 -0.003304  0.010943
# 22     0.009107    0.026606    -0.008598  0.007975 -0.002992 -0.007680
# 23    -0.003610   -0.003847    -0.022405  0.004009 -0.002838 -0.003480
# 24    -0.001812   -0.012724     0.006995  0.007776 -0.004554 -0.021944
# 25    -0.012704   -0.009682    -0.026317  0.010635 -0.000245 -0.014443
# 26     0.005515   -0.005989    -0.011484 -0.009698  0.006619 -0.000703
# 27    -0.005484   -0.000782     0.007158  0.021356  0.008768  0.002381
# 28     0.003676   -0.007464    -0.014390  0.006936 -0.000563 -0.013982
# 29    -0.018315   -0.006305    -0.002483  0.020766 -0.008294  0.010621
# 30     0.011194    0.002842    -0.029983 -0.000595 -0.016077  0.006555
# ..          ...         ...          ...       ...       ...       ...
# 468    0.027721   -0.002416     0.005554  0.019629  0.000943  0.011288
# 469   -0.012987   -0.008718    -0.005428 -0.019608  0.006427 -0.013080
# 470   -0.029352   -0.002589    -0.003112 -0.033818  0.002639 -0.012524
# 471    0.039625    0.005143    -0.017673  0.005269 -0.007982  0.006816
# 472    0.007021   -0.006774     0.003715 -0.007488  0.019432 -0.010643
# 473   -0.000996    0.002110     0.001169 -0.015466 -0.007557  0.007125
# 474   -0.021934   -0.007148    -0.012649  0.006897  0.023437  0.001296
# 475    0.028542    0.000740     0.005322 -0.018645  0.003555 -0.013920
# 476    0.054509    0.004829     0.002402  0.019000  0.008238 -0.024368
# 477    0.026316    0.007454     0.010806  0.004566 -0.005474 -0.010034
# 478   -0.004579    0.005306     0.030620  0.000379  0.004436  0.006537
# 479   -0.003680   -0.005423    -0.010513 -0.079894 -0.009161  0.007844
# 480   -0.060942   -0.011685     0.008775 -0.042387  0.002807 -0.026065
# 481    0.004916    0.012857    -0.005172  0.014181  0.005515 -0.010482
# 482    0.031311   -0.004572    -0.000095  0.025000  0.002456 -0.011232
# 483   -0.037951    0.006401     0.011345  0.009508 -0.023765  0.000684
# 484   -0.045365   -0.003156    -0.006076 -0.017609 -0.016814  0.008276
# 485   -0.072314   -0.035309    -0.022102 -0.100459 -0.005956  0.011221
# 486   -0.010022    0.083300     0.004376  0.021779 -0.002397 -0.010649
# 487   -0.013498   -0.019760     0.027578 -0.003175 -0.018104  0.013097
# 488   -0.023945    0.015213    -0.026792 -0.034577  0.014331 -0.014526
# 489   -0.030374   -0.015266    -0.018576 -0.049010 -0.005600 -0.019980
# 490   -0.003614    0.006230    -0.011562 -0.014371 -0.001126 -0.013540
# 491   -0.009674    0.006097    -0.006909  0.024635 -0.034692 -0.015442
# 492    0.012210    0.003711    -0.023059  0.051521  0.087511  0.005030
# 493   -0.072376   -0.022979    -0.002289 -0.056463 -0.015202 -0.003389
# 494    0.000000    0.000000    -0.004487  0.000000 -0.009648 -0.017319
# 495    0.000000    0.000000     0.000000  0.000000 -0.002118  0.000000
# 496    0.000000    0.000000     0.000000  0.000000  0.001698  0.000000
# 497    0.000000    0.000000     0.000000  0.000000 -0.025593  0.000000
#
# [497 rows x 6 columns]

# %%
sns.pairplot(pct_data)

# %% [markdown]
# # Query 2.7
#  Volatility is the change in variance in the returns of a stock over a specific period of time.Do give the following documentation on volatility a read.
# You have already calculated the percentage changes in several stock prices. Calculate the 7 day rolling average of the percentage change of any of the stock prices, then compute the standard deviation (which is the square root of the variance) and plot the values.

# %%
pc_relinf=relinf['Close Price'].pct_change()
pc_relinf[0]=0

# %%
plt.figure()
fig=plt.figure(figsize=(15,8))
ax=pc_relinf.rolling(7).std().plot(label="AJANTA")
nifty_volatility.plot(ax=ax,label="NIFTY")
ax.set(xlabel='Moving Averages',ylabel='Volatility')
ax.set_title(label='Volatility')
ax.legend()

# %% [markdown]
# # Query 2.9
# Trade Calls - Using Simple Moving Averages.
# Plot the 21 day and 34 day Moving average with the average price and decide a Call !
# Call should be buy whenever the smaller moving average (21) crosses over longer moving average (34) AND the call should be sell whenever smaller moving average crosses under longer moving average.
# One of the most widely used technical indicators.

# %%
day21_roll=data['Average Price'].rolling(21).mean()
day34_roll=data['Average Price'].rolling(34).mean()

# %%
fig,ax=plt.subplots(figsize=(12,8))
day21_roll.plot(ax=ax,label='21day_rolling',color='black')
day34_roll.plot(ax=ax,label='34day_rolling')
signals = pd.DataFrame(index=data.index)
signals['signal'] = 0.0
signals['21day_roll'] = day21_roll
signals['34_dayroll'] = day34_roll
signals['signal'][0:] = np.where(signals['21day_roll'][0:]  > signals['34_dayroll'][0:], 1.0, 0.0)   

signals['positions'] = signals['signal'].diff()
data['Close Price'].plot(ax=ax,label='daily_close')


ax.plot(signals.loc[signals.positions == 1.0].index, 
         signals['21day_roll'][signals.positions == 1.0],
         '^', markersize=10,label='buy', color='g')
         
ax.plot(signals.loc[signals.positions == -1.0].index, 
         signals['21day_roll'][signals.positions == -1.0],
         'v', markersize=10,label='sell', color='k')
ax.set(xlabel="Date",ylabel="Price in Rupees")
ax.legend()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.setp(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# # Query 2.10
# Trade Calls - Using Bollinger Bands
# Plot the bollinger bands for this stock - the duration of 14 days and 2 standard deviations away from the average
# The bollinger bands comprise the following data points-
# The 14 day rolling mean of the closing price (we call it the average)
# Upper band which is the rolling mean + 2 standard deviations away from the average.
# Lower band which is the rolling mean - 2 standard deviations away from the average.
# Average Daily stock price.
# Bollinger bands are extremely reliable , with a 95% accuracy at 2 standard deviations , and especially useful in sideways moving market.
# Observe the bands yourself , and analyse the accuracy of all the trade signals provided by the bollinger bands.
# Save to a new csv file.

# %%
middle_band = data['Close Price'].rolling(window=14).mean()
std = data['Close Price'].rolling(window=14).std()
upper_band = middle_band + 2* std
lower_band = middle_band - 2* std

# %%
fig=plt.figure(figsize=(15,8))
ax=upper_band.plot(label='upper')
lower_band.plot(ax=ax,label='lower')
middle_band.plot(ax=ax,label='sma')
data['Average Price'].plot(ax=ax,label='actual close',linewidth=0.5)
ax.set(xlabel='Date')
ax.set_title(label='Trade Calls - Using Bollinger Bands ')
ax.legend()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.setp(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# Bollinger bands are based on the concept of volatility.
# Drop in price is observed whenever the space between the moving average plots i.e., increases and vice versa.
# Increase in volatility means an unreliable stock and in turn leads to selling/drop call which leads to decrease in value of the stock.

# %%
data.to_csv('week3.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8ef5be6010ac> in <module>()
# ----> 1 data.to_csv('week3.csv')
#
# NameError: name 'data' is not defined
