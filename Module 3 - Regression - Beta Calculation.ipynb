# %% [markdown]
# # Module 3- Regression & Beta Calculation

# %% [markdown]
#    ### Welcome to the Answer notebook for Module 3 !
# Make sure that you've submitted the module 2 notebook and unlocked Module 3 yourself before you start coding here

# %% [markdown]
# ### Query 3.1
# Import the file 'gold.csv', which is contains the data about last 2 years price action of Indian(MCX) gold standard. Explore the dataframe. You'd see 2 unique columns - 'Pred' and 'new'.
#
# One of the 2 columns is a linear combination of the OHLC prices with varying coefficients while the other is a polynomial fucntion of the same inputs. Also, one of the 2 columns is partially filled.
#
# >Using linear regression, find the coefficients of the inputs and using the same trained model, complete the
#       entire column.
#
# >Also, try to fit the other column as well using a new linear regression model. Check if the predicitons are
#       accurate.
#       Mention which column is a linear function and which is a polynomial function.
#       (Hint: Plotting a histogram & distplot helps in recognizing the  discrepencies in prediction, if any.)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
gold=pd.read_csv('GOLD.csv',parse_dates=['Date'])
gold
# Out:
#           Date  Price   Open   High    Low    Vol. Change %   Pred         new
# 0   2017-05-04  28060  28400  28482  28025   0.08K   -1.79%  738.0  117.570740
# 1   2017-05-05  28184  28136  28382  28135   0.06K    0.44% -146.0  295.430176
# 2   2017-05-08  28119  28145  28255  28097   7.85K   -0.23%   30.0  132.123714
# 3   2017-05-09  27981  28125  28192  27947  10.10K   -0.49%  357.0  101.298064
# 4   2017-05-10  28007  28060  28146  27981   9.28K    0.09%  124.0  112.153318
# 5   2017-05-11  28022  27995  28100  27945   9.72K    0.05%  149.0  182.427089
# 6   2017-05-12  28019  28088  28195  27985   9.48K   -0.01%  167.0  141.255137
# 7   2017-05-15  28008  28049  28157  27996   8.76K   -0.04%   22.0  120.069010
# 8   2017-05-16  28109  28025  28159  28025   7.73K    0.36%   34.0  218.401641
# 9   2017-05-17  28614  28170  28638  28170  15.92K    1.80%  420.0  919.376358
# 10  2017-05-18  28710  28666  28980  28551  23.80K    0.34%  234.0  475.389093
# 11  2017-05-19  28634  28660  28779  28531  13.16K   -0.26%  345.0  222.895307
# 12  2017-05-22  28783  28590  28799  28568   9.31K    0.52%  265.0  425.738484
# 13  2017-05-23  28808  28804  28930  28740  12.50K    0.09%  138.0  194.449548
# 14  2017-05-24  28719  28770  28770  28650   8.69K   -0.31%  378.0   69.289005
# 15  2017-05-25  28638  28769  28770  28600   9.93K   -0.28%  413.0   39.225874
# 16  2017-05-26  28847  28694  28866  28674   9.52K    0.73%  214.0  346.158401
# 17  2017-05-29  28874  28843  28928  28807   4.56K    0.09%  121.0  152.281425
# 18  2017-05-30  28704  28921  28960  28680   9.88K   -0.59%  491.0   63.234310
# 19  2017-05-31  28905  28683  28950  28628   7.83K    0.70%  397.0  547.115621
# 20  2017-06-01  28749  28877  28877  28712   1.77K   -0.54%  404.0   37.212629
# 21  2017-06-02  28949  28685  29011  28680   0.31K    0.70%  222.0  598.104568
# 22  2017-06-05  29111  29045  29180  29045   0.71K    0.56%   -3.0  201.306765
# 23  2017-06-06  29481  29220  29499  29216  11.14K    1.27%  259.0  546.566915
# 24  2017-06-07  29376  29439  29485  29310   9.82K   -0.36%  344.0  112.394063
# 2019-03-28  31624  31993  32030  31591  15.06K   -1.23%    NaN   70.458580
# 2019-03-29  31703  31600  31788  31510  11.36K    0.25%    NaN  382.702761
# 2019-04-01  31570  31588  31730  31542   4.52K   -0.42%    NaN  170.166889
# 2019-04-02  31535  31550  31590  31359   0.39K   -0.11%    NaN  217.296470
# 2019-04-03  31450  31499  31607  31318   0.17K   -0.27%    NaN  241.218085
# 2019-04-04  31503  31499  31549  31350   0.07K    0.17%    NaN  203.971196
# 2019-04-05  31566  31535  31620  31400   0.06K    0.20%    NaN  252.163057
# 2019-04-08  32076  31795  32155  31795  12.90K    1.62%    NaN  644.181632
# 2019-04-09  32098  32131  32171  32020  11.01K    0.07%    NaN  118.367833
# 2019-04-10  32174  32070  32197  31968  11.74K    0.24%    NaN  334.475663
# 2019-04-11  31663  32148  32148  31638  17.11K   -1.59%    NaN   25.402996
# 2019-04-12  31760  31721  31871  31705  11.01K    0.31%    NaN  205.287967
# 2019-04-15  31760  31710  31791  31570   8.54K    0.00%    NaN  272.330060
# 2019-04-16  31474  31700  31768  31453  14.48K   -0.90%    NaN   89.210314
# 2019-04-17  31410  31500  31525  31393   5.65K   -0.20%    NaN   42.071481
# 2019-04-18  31403  31474  31544  31355   9.87K   -0.02%    NaN  118.289332
# 2019-04-22  31531  31497  31697  31497   9.89K    0.41%    NaN  234.215894
# 2019-04-23  31525  31490  31566  31401   9.92K   -0.02%    NaN  200.651572
# 2019-04-24  31759  31480  31799  31450  12.64K    0.74%    NaN  631.428967
# 2019-04-25  31843  31750  31926  31641  11.64K    0.26%    NaN  379.819475
# 2019-04-26  31868  31851  31934  31705   9.67K    0.08%    NaN  247.177322
# 2019-04-30  31625  31800  31824  31597   6.44K   -0.76%    NaN   52.201158
# 2019-05-01  31563  31604  31657  31503   1.55K   -0.20%    NaN  113.293305
# 2019-05-02  31203  31420  31425  31160   0.48K   -1.14%    NaN   48.365693
# 2019-05-03  31341  31250  31500  31163   0.08K    0.44%    NaN  429.924911
#
# [512 rows x 8 columns]

# %%
gold.corr()
# Out:
#           Price      Open      High       Low      Pred       new
# Price  1.000000  0.989758  0.995125  0.996830  0.040489  0.164504
# Open   0.989758  1.000000  0.995988  0.993992  0.109153  0.058551
# High   0.995125  0.995988  1.000000  0.994194  0.080394  0.142109
# Low    0.996830  0.993992  0.994194  1.000000  0.014411  0.091895
# Pred   0.040489  0.109153  0.080394  0.014411  1.000000 -0.006109
# new    0.164504  0.058551  0.142109  0.091895 -0.006109  1.000000

# %%
gold1=gold.dropna()
X=gold1[['Open','Price','High','Low']]
Y=gold1['Pred']

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -6.087930159992538e-11
# Coefficients:
#  [ 3.  2. -1. -4.]

# %%
colist=[]
for coef in regr.coef_:
    colist.append(coef)
gold['Pred']=gold.apply(lambda row: colist[0]* row.Open + colist[1]*row.Price + colist[2]*row.High + colist[3]*row.Low + regr.intercept_ if np.isnan(row.Pred) else row.Pred, axis=1)
gold
# Out:
#             Price   Open   High    Low    Vol. Change %    Pred         new
# Date
# 2019-04-01  31570  31588  31730  31542   4.52K   -0.42%     6.0  170.166889
# 2019-04-02  31535  31550  31590  31359   0.39K   -0.11%   694.0  217.296470
# 2019-04-03  31450  31499  31607  31318   0.17K   -0.27%   518.0  241.218085
# 2019-04-04  31503  31499  31549  31350   0.07K    0.17%   554.0  203.971196
# 2019-04-05  31566  31535  31620  31400   0.06K    0.20%   517.0  252.163057
# 2019-04-08  32076  31795  32155  31795  12.90K    1.62%   202.0  644.181632
# 2019-04-09  32098  32131  32171  32020  11.01K    0.07%   338.0  118.367833
# 2019-04-10  32174  32070  32197  31968  11.74K    0.24%   489.0  334.475663
# 2019-04-11  31663  32148  32148  31638  17.11K   -1.59%  1070.0   25.402996
# 2019-04-12  31760  31721  31871  31705  11.01K    0.31%    -8.0  205.287967
# 2019-04-15  31760  31710  31791  31570   8.54K    0.00%   579.0  272.330060
# 2019-04-16  31474  31700  31768  31453  14.48K   -0.90%   468.0   89.210314
# 2019-04-17  31410  31500  31525  31393   5.65K   -0.20%   223.0   42.071481
# 2019-04-18  31403  31474  31544  31355   9.87K   -0.02%   264.0  118.289332
# 2019-04-22  31531  31497  31697  31497   9.89K    0.41%  -132.0  234.215894
# 2019-04-23  31525  31490  31566  31401   9.92K   -0.02%   350.0  200.651572
# 2019-04-24  31759  31480  31799  31450  12.64K    0.74%   359.0  631.428967
# 2019-04-25  31843  31750  31926  31641  11.64K    0.26%   446.0  379.819475
# 2019-04-26  31868  31851  31934  31705   9.67K    0.08%   535.0  247.177322
# 2019-04-30  31625  31800  31824  31597   6.44K   -0.76%   438.0   52.201158
# 2019-05-01  31563  31604  31657  31503   1.55K   -0.20%   269.0  113.293305
# 2019-05-02  31203  31420  31425  31160   0.48K   -1.14%   601.0   48.365693
# 2019-05-03  31341  31250  31500  31163   0.08K    0.44%   280.0  429.924911
#
# [512 rows x 8 columns]

# %%
X1=gold[['Open','Price','High','Low']]
Y1=gold['new']
regr2 = linear_model.LinearRegression()
regr2.fit(X1, Y1)
Y_=regr2.predict(X1)
sns.pairplot(gold,y_vars=['Pred','new'],x_vars=['Price','Open','High','Low'],kind='reg')

# %%
gold['new'].plot(kind="line")

# %%
sns.distplot(gold['Pred'])
# Out:
# /opt/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred=lin_reg.predict(X_test)

# %%
from sklearn import metrics
print(metrics.mean_absolute_error(y_pred,y_test));print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 0.41818243762314744
# 0.5451580164786946

# %%
from sklearn.preprocessing import PolynomialFeatures
lin_regressor = LinearRegression()

# pass the order of your polynomial here  
poly = PolynomialFeatures(2)

# convert to be used further to linear regression
X_transform = poly.fit_transform(X_train)

# fit this to Linear Regressor
lin_regressor.fit(X_transform,y_train) 
X_testtrans=poly.fit_transform(X_test)

# get the predictions
y_preds = lin_regressor.predict(X_testtrans)

# %%
X_transform.shape
# Out:
# (409, 15)

# %%
print(metrics.mean_absolute_error(y_preds,y_test));
print(np.sqrt(metrics.mean_squared_error(y_test,y_preds)))
# Out:
# 0.012626603112088219
# 0.018003636108529696

# %% [markdown]
# From the metrics,we can tell that the Polynomial model best suits for th3 new column than the Pred column.So,we fit the new column using the polynomial regression model trained before.

# %%
lin_regressor.fit(poly.fit_transform(X1),Y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
sns.distplot(gold['new'])
# Out:
# /opt/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# The distribution plots are almost smooth.So,we can assume that our regression models fit the given values.

# %% [markdown]
# # Query 3.2
# Import the stock of your choosing AND the Nifty index.
# Using linear regression (OLS), calculate -
# The daily Beta value for the past 3 months. (Daily= Daily returns)
# The monthly Beta value. (Monthly= Monthly returns)
# Refrain from using the (covariance(x,y)/variance(x)) formula.
# Attempt the question using regression.(Regression Reference)
# Were the Beta values more or less than 1 ? What if it was negative ?
# Discuss. Include a brief writeup in the bottom of your jupyter notebook with your inferences from the Beta values and regression results

# %%
nifty=pd.read_csv('Nifty50.csv',parse_dates=['Date'])
pd.to_datetime(nifty['Date'])
nifty.set_index('Date',drop=True,inplace=True)

# %%
daily_returns_nifty=((nifty['Close'].pct_change())*100).dropna(axis=0).last('3M')

# %%
daily_returns_nifty.head()
# Out:
# Date
# 2019-03-01    0.657864
# 2019-03-05    1.140977
# 2019-03-06    0.596590
# 2019-03-07    0.047046
# 2019-03-08   -0.206182
# Name: Close, dtype: float64

# %%
data=pd.read_csv('week2.csv',parse_dates=['Date'])
pd.to_datetime(data['Date'])
data.set_index('Date',drop=True,inplace=True)

# %%
data
# Out:
#                 Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15  AJANTPHARM     EQ     1616.30     1610.00     1643.40    1601.00
# 2017-05-16  AJANTPHARM     EQ     1633.50     1632.50     1643.45    1610.00
# 2017-05-17  AJANTPHARM     EQ     1634.25     1620.50     1668.00    1620.50
# 2017-05-18  AJANTPHARM     EQ     1654.35     1640.25     1663.95    1621.85
# 2017-05-19  AJANTPHARM     EQ     1633.40     1640.00     1681.20    1621.50
# 2017-05-22  AJANTPHARM     EQ     1670.25     1670.00     1692.00    1648.00
# 2017-05-23  AJANTPHARM     EQ     1677.95     1687.80     1696.95    1619.00
# 2017-05-24  AJANTPHARM     EQ     1676.80     1672.00     1693.00    1623.30
# 2017-05-25  AJANTPHARM     EQ     1657.45     1650.00     1654.85    1578.05
# 2017-05-26  AJANTPHARM     EQ     1616.15     1615.00     1625.40    1569.15
# 2017-05-29  AJANTPHARM     EQ     1602.15     1597.00     1599.90    1401.65
# 2017-05-30  AJANTPHARM     EQ     1536.30     1520.20     1565.05    1518.00
# 2017-05-31  AJANTPHARM     EQ     1549.00     1560.00     1588.95    1541.40
# 2017-06-01  AJANTPHARM     EQ     1569.80     1569.00     1615.40    1560.00
# 2017-06-02  AJANTPHARM     EQ     1606.40     1629.00     1629.60    1589.00
# 2017-06-05  AJANTPHARM     EQ     1607.55     1613.00     1628.00    1595.00
# 2017-06-06  AJANTPHARM     EQ     1604.40     1618.00     1618.00    1571.65
# 2017-06-07  AJANTPHARM     EQ     1580.85     1580.85     1585.60    1558.00
# 2017-06-08  AJANTPHARM     EQ     1562.90     1577.00     1600.00    1557.00
# 2017-06-09  AJANTPHARM     EQ     1569.10     1572.00     1592.00    1558.25
# 2017-06-12  AJANTPHARM     EQ     1570.55     1560.00     1580.00    1549.50
# 2017-06-13  AJANTPHARM     EQ     1559.50     1557.00     1565.90    1541.00
# 2017-06-14  AJANTPHARM     EQ     1544.75     1545.00     1590.00    1521.75
# 2017-06-15  AJANTPHARM     EQ     1585.85     1587.00     1601.00    1570.20
# 2017-06-16  AJANTPHARM     EQ     1579.75     1575.00     1592.10    1548.00
# 2017-06-19  AJANTPHARM     EQ     1559.65     1568.00     1569.95    1533.50
# 2017-06-20  AJANTPHARM     EQ     1544.55     1542.70     1549.00    1507.20
# 2017-06-21  AJANTPHARM     EQ     1535.30     1540.00     1547.45    1521.05
# 2017-06-22  AJANTPHARM     EQ     1534.10     1544.00     1545.50    1516.15
# 2017-06-23  AJANTPHARM     EQ     1522.65     1522.75     1533.60    1506.00
# ...                ...    ...         ...         ...         ...        ...
# 2019-03-27  AJANTPHARM     EQ     1010.95     1014.80     1024.00     979.10
# 2019-03-28  AJANTPHARM     EQ     1000.95     1008.00     1030.80    1005.30
# 2019-03-29  AJANTPHARM     EQ     1025.40     1030.00     1064.40    1028.10
# 2019-04-01  AJANTPHARM     EQ     1035.20     1038.10     1050.00    1028.55
# 2019-04-02  AJANTPHARM     EQ     1034.90     1046.00     1047.45    1021.60
# 2019-04-03  AJANTPHARM     EQ     1032.40     1032.50     1039.75    1016.15
# 2019-04-04  AJANTPHARM     EQ     1023.40     1023.70     1030.00    1008.75
# 2019-04-05  AJANTPHARM     EQ     1020.75     1025.00     1036.50    1015.85
# 2019-04-08  AJANTPHARM     EQ     1026.00     1029.20     1037.00    1010.60
# 2019-04-09  AJANTPHARM     EQ     1019.05     1020.05     1025.90    1008.00
# 2019-04-10  AJANTPHARM     EQ     1021.20     1017.00     1023.95    1008.55
# 2019-04-11  AJANTPHARM     EQ     1013.90     1018.40     1022.00    1009.00
# 2019-04-12  AJANTPHARM     EQ     1014.65     1017.85     1029.40    1014.65
# 2019-04-15  AJANTPHARM     EQ     1019.55     1020.50     1030.00    1019.50
# 2019-04-16  AJANTPHARM     EQ     1027.15     1031.00     1050.00    1028.05
# 2019-04-18  AJANTPHARM     EQ     1032.60     1043.00     1043.00    1018.90
# 2019-04-22  AJANTPHARM     EQ     1027.00     1020.00     1020.00    1001.25
# 2019-04-23  AJANTPHARM     EQ     1015.00     1013.00     1038.00    1009.00
# 2019-04-24  AJANTPHARM     EQ     1028.05     1029.05     1039.50    1016.00
# 2019-04-25  AJANTPHARM     EQ     1023.35     1022.00     1046.00    1022.00
# 2019-04-26  AJANTPHARM     EQ     1029.90     1025.20     1037.30    1006.30
# 2019-04-30  AJANTPHARM     EQ     1026.65     1032.65     1035.00     984.00
# 2019-05-02  AJANTPHARM     EQ      990.40      970.00     1089.40     970.00
# 2019-05-03  AJANTPHARM     EQ     1072.90     1060.00     1084.65    1041.00
# 2019-05-06  AJANTPHARM     EQ     1051.70     1030.00     1075.00    1028.45
# 2019-05-07  AJANTPHARM     EQ     1067.70     1075.00     1080.00    1046.00
# 2019-04-26                    5.49      4  2019        -0.315565
# 2019-04-30                   15.73      4  2019        -3.530901
# 2019-05-02                    7.38      5  2019         8.329968
# 2019-05-03                    4.46      5  2019        -1.975953
# 2019-05-06                   19.24      5  2019         1.521346
# 2019-05-07                    6.64      5  2019        -1.526646
# 2019-05-08                   13.30      5  2019         0.622979
# 2019-05-09                   10.62      5  2019         0.609670
# 2019-05-10                   11.48      5  2019         0.371101
# 2019-05-13                   10.48      5  2019        -2.297936
#
#                           Trend
# Date
# 2017-05-15  Slight or No change
# 2017-05-16  Slight or No change
# 2017-05-17             Positive
# 2017-05-18             Negative
# 2017-05-19             Positive
# 2017-05-22  Slight or No change
# 2017-05-23  Slight or No change
# 2017-05-24             Negative
# 2017-05-25             Negative
# 2017-05-26      Slight Negative
# 2017-05-29     Among top losers
# 2017-05-30      Slight Positive
# 2017-05-31             Positive
# 2017-06-01             Positive
# 2017-06-02  Slight or No change
# 2017-06-05  Slight or No change
# 2017-06-06             Negative
# 2017-06-07             Negative
# 2017-06-08  Slight or No change
# 2017-06-09  Slight or No change
# 2017-06-12      Slight Negative
# 2017-06-13      Slight Negative
# 2017-06-14             Positive
# 2017-06-15  Slight or No change
# 2017-06-16             Negative
# 2017-06-19      Slight Negative
# 2017-06-20      Slight Negative
# 2017-06-21  Slight or No change
# 2017-06-22      Slight Negative
# 2017-06-23      Slight Negative
# ...                         ...
# 2019-03-27      Slight Negative
# 2019-03-28             Positive
# 2019-03-29      Slight Positive
# 2019-04-01  Slight or No change
# 2019-04-02  Slight or No change
# 2019-04-03      Slight Negative
# 2019-04-04  Slight or No change
# 2019-04-05      Slight Positive
# 2019-04-08      Slight Negative
# 2019-04-09  Slight or No change
# 2019-04-10      Slight Negative
# 2019-04-11  Slight or No change
# 2019-04-12  Slight or No change
# 2019-04-15      Slight Positive
# 2019-04-16      Slight Positive
# 2019-04-18      Slight Negative
# 2019-04-22             Negative
# 2019-04-23             Positive
# 2019-04-24  Slight or No change
# 2019-04-25      Slight Positive
# 2019-04-26  Slight or No change
# 2019-04-30     Among top losers
# 2019-05-02             Bull run
# 2019-05-03             Negative
# 2019-05-06             Positive
# 2019-05-07             Negative
# 2019-05-08      Slight Positive
# 2019-05-09      Slight Positive
# 2019-05-10  Slight or No change
# 2019-05-13             Negative
#
# [494 rows x 18 columns]

# %%
daily_returns_stock=data['Day_Perc_Change'].dropna(axis=0).last('3M')

# %%
daily_returns_stock.head()
# Out:
# Date
# 2019-03-01    0.832567
# 2019-03-05    0.547085
# 2019-03-06   -0.050380
# 2019-03-07   -1.865013
# 2019-03-08   -1.751502
# Name: Day_Perc_Change, dtype: float64

# %%
import statsmodels.api as sm
# split dependent and independent variable
X = daily_returns_nifty
y = daily_returns_stock

# Add a constant to the independent value
X1 = sm.add_constant(X)

# make regression model 
model = sm.OLS(y, X1)

# fit model and print results
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Day_Perc_Change   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     4.829
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):             0.0333
# Time:                        21:19:43   Log-Likelihood:                -94.412
# No. Observations:                  46   AIC:                             192.8
# Df Residuals:                      44   BIC:                             196.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0945      0.286      0.331      0.742      -0.481       0.670
# Close          0.8812      0.401      2.198      0.033       0.073       1.689
# ==============================================================================
# Omnibus:                       36.541   Durbin-Watson:                   2.795
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              127.479
# Skew:                           1.958   Prob(JB):                     2.08e-28
# Kurtosis:                      10.154   Cond. No.                         1.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Beta value is the coefficient of Close i.e., 0.8812

# %%
monthly=nifty.resample('BM').apply( lambda x:x[-1])
monthly_returns_nifty=((monthly['Close'].pct_change())*100).dropna(axis=0)

# %%
monthly_returns_nifty
# Out:
# Date
# 2017-06-30   -1.043004
# 2017-07-31    5.841885
# 2017-08-31   -1.579820
# 2017-09-29   -1.303703
# 2017-10-31    5.585068
# 2017-11-30   -1.052219
# 2017-12-29    2.974121
# 2018-01-31    4.719534
# 2018-02-28   -4.850059
# 2018-03-30   -3.613413
# 2018-04-30    6.186163
# 2018-05-31   -0.029797
# 2018-06-29   -0.203518
# 2018-07-31    5.993859
# 2018-08-31    2.852992
# 2018-09-28   -6.421386
# 2018-10-31   -4.975550
# 2018-11-30    4.719061
# 2018-12-31   -0.130554
# 2019-01-31   -0.290908
# 2019-02-28   -0.355001
# 2019-03-29    7.703498
# 2019-04-30    1.068918
# 2019-05-31   -5.106761
# Freq: BM, Name: Close, dtype: float64

# %%
monthly_stock=data.resample('BM').apply( lambda x:x[-1])
monthly_returns_stock=((monthly_stock['Close Price'].pct_change())*100).dropna(axis=0)

# %%
monthly_returns_stock.head()
# Out:
# Date
# 2017-06-30    -1.586189
# 2017-07-31    -9.563726
# 2017-08-31   -14.543893
# 2017-09-29    -4.954144
# 2017-10-31     7.512337
# Freq: BM, Name: Close Price, dtype: float64

# %%
X = monthly_returns_nifty
y = monthly_returns_stock

# Add a constant to the independent value
X1 = sm.add_constant(X)

# make regression model 
model = sm.OLS(y, X1)

# fit model and print results
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Close Price   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     3.048
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):             0.0948
# Time:                        21:19:43   Log-Likelihood:                -88.307
# No. Observations:                  24   AIC:                             180.6
# Df Residuals:                      22   BIC:                             183.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.7418      2.075     -0.840      0.410      -6.044       2.561
# Close          0.8908      0.510      1.746      0.095      -0.167       1.949
# ==============================================================================
# Omnibus:                        4.890   Durbin-Watson:                   1.602
# Prob(Omnibus):                  0.087   Jarque-Bera (JB):                3.046
# Skew:                          -0.811   Prob(JB):                        0.218
# Kurtosis:                       3.643   Cond. No.                         4.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [raw]
# The Slope of the Regression line from the graph is given as the coefficient of Close i.e., 0.8908.
# This is the beta value.

# %% [markdown]
# Beta value of the stock is 0.89.
# This indicates that the volatility of our stock is less than most of the other stocks and it is steadier and slower.
# If Beta is greater than 1,the risk is higher and if beta is less than 1,it indicates a negative relation with the national stock index.It suggests an inverse relationship.

# %%
model.predict([[1,2,3]])
